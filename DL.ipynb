# %%
#pip install tensorflow

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow
import keras

# %%
df=pd.read_csv("Churn_Modelling.csv")

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
df=df.drop(["RowNumber","CustomerId","Surname"],axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df=pd.get_dummies(df,columns=["Gender","Geography"])

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_Female  Gender_Male  \
# 0               1        101348.88       1           True        False
# 1               1        112542.58       0           True        False
# 2               0        113931.57       1           True        False
# 3               0         93826.63       0           True        False
# 4               1         79084.10       0           True        False
#
#    Geography_France  Geography_Germany  Geography_Spain
# 0              True              False            False
# 1             False              False             True
# 2              True              False            False
# 3              True              False            False
# 4             False              False             True

# %%
df.dtypes
# Out:
# CreditScore            int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Gender_Female           bool
# Gender_Male             bool
# Geography_France        bool
# Geography_Germany       bool
# Geography_Spain         bool
# dtype: object

# %%
X=df.drop("Exited",axis=1)
Y=df[["Exited"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(units=6,activation="relu",input_dim=13))
model.add(Dense(units=5,activation="relu"))
model.add(Dense(units=1,activation="sigmoid"))
# Out:
# C:\Users\Premalatha\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_train,Y_train,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2266 - loss: 33910.5273 - val_accuracy: 0.4371 - val_loss: 5067.9165
# Epoch 2/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4785 - loss: 3118.8833 - val_accuracy: 0.5571 - val_loss: 1107.5796
# Epoch 3/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5403 - loss: 828.4933 - val_accuracy: 0.8214 - val_loss: 3.6635
# Epoch 4/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7880 - loss: 2.3747 - val_accuracy: 0.8214 - val_loss: 1.1657
# Epoch 5/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8029 - loss: 0.7806 - val_accuracy: 0.8229 - val_loss: 0.5410
# Epoch 6/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7991 - loss: 0.5831 - val_accuracy: 0.8214 - val_loss: 0.5303
# Epoch 7/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7947 - loss: 0.5460 - val_accuracy: 0.8214 - val_loss: 0.5193
# Epoch 8/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7911 - loss: 0.5403 - val_accuracy: 0.8214 - val_loss: 0.5099
# Epoch 9/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7966 - loss: 0.5286 - val_accuracy: 0.8214 - val_loss: 0.5019
# Epoch 10/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7971 - loss: 0.5223 - val_accuracy: 0.8214 - val_loss: 0.4954
